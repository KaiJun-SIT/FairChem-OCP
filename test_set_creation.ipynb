# %% [markdown]
# # This notebook is to create atomic strucutres and then LMDB to be the input of ML model (derived from OCP)

# %%
import pickle
import json
import lmdb
import pandas as pd

from ase import Atoms, Atom
from ase.visualize import view
from ase.constraints import dict2constraint
from ase.calculators.singlepoint import SinglePointCalculator
from ase.io import write

from pymatgen.core.structure import Structure
from pymatgen.io.ase import AseAtomsAdaptor
from pymatgen.ext.matproj import MPRester

from ocpmodels.preprocessing import AtomsToGraphs
from ocpmodels.datasets import SinglePointLmdbDataset

# %% [markdown]
# # Retrieve dataset

# %%
with open('docs.pkl', 'rb') as file_handle:
    docs = pickle.load(file_handle)
co_set = [doc for doc in docs if doc['adsorbate'] == 'CO']
h_set = [doc for doc in docs if doc['adsorbate'] == 'H']
oh_set = [doc for doc in docs if doc['adsorbate'] == 'OH']
print(len(co_set),len(h_set),len(oh_set))
# Out:
# 19101 22857 6512

# %%
for a, item in enumerate(co_set):
    if len(item['atoms']['symbol_counts']) == 3:
        try:
            print(item['atoms']['symbol_counts']['Sn'], a)
        except KeyError:
            None
# Out:
# 16 764
# 6 1109
# 16 1623
# 16 3086
# 8 3196
# 12 4254
# 6 4430
# 6 4553
# 12 5074
# 12 5517
# 6 5944
# 8 7605
# 8 7833
# 16 9535
# 12 11365
# 16 11689
# 16 11924
# 8 11970
# 12 12015
# 12 12955
# 6 13050
# 12 13420
# 16 13555
# 12 14185
# 8 14314
# 16 14514
# 8 14843
# 16 15633
# 12 16775
# 12 17040
# 8 17120
# 6 18697

# %% [markdown]
# # Multiple facet for one element

# %%
m = MPRester('7zd0wqmMOTujHS0Zxp')
data = pd.DataFrame(m.query(criteria = {"elements": {"$in": ['Al']}, "nelements": 1}, 
                            properties = ['task_id', 'pretty_formula',  'spacegroup.crystal_system',
                                       'spacegroup.symbol']))
data
# Out:
#       task_id pretty_formula spacegroup.crystal_system spacegroup.symbol
# 0  mp-1239196             Al                tetragonal            I4/mmm
# 1  mp-1183144             Al                 hexagonal          P6_3/mmc
# 2      mp-134             Al                     cubic             Fm-3m
# 3  mp-1245307             Al                 triclinic                P1
# 4   mp-998860             Al                     cubic             Im-3m
# 5  mp-1245067             Al                 triclinic                P1
# 6  mp-1244953             Al                 triclinic                P1
# 7  mp-1245152             Al                 triclinic                P1
# 8  mp-1245129             Al                 triclinic                P1

# %% [markdown]
# # Choose element and facet

# %%
#Defaults
Cu_FCC_id = 'mp-30'
Ni_FCC_id = 'mp-23'
Zn_HCP_id = 'mp-79'
Sn_BCT_id = 'mp-55'
Ag_FCC_id = 'mp-124'
Au_FCC_id = 'mp-81'
Al_FCC_id = 'mp-134'
CO = Atoms('CO', positions=[[0., 0., 0.],[0., 0., 1.2]])
H = Atoms('H', positions=[[0., 0., -0.5]])
OH = Atoms('OH', positions=[[0., 0., 0.],[0.92, 0., 0.32]])
#{111}, {100} and {110} facets, which are usually present in the equilibrium crystal shape of FCC metals
#HCP 0001

# %% [markdown]
# # View atoms object from dataset

# %%
def make_atoms_from_doc(doc):
    '''
    This is the inversion function for `make_doc_from_atoms`; it takes
    Mongo documents created by that function and turns them back into
    an ase.Atoms object.

    Args:
        doc     Dictionary/json/Mongo document created by the
                `make_doc_from_atoms` function.
    Returns:
        atoms   ase.Atoms object with an ase.SinglePointCalculator attached
    '''
    atoms = Atoms([Atom(atom['symbol'],
                        atom['position'],
                        tag=atom['tag'],
                        momentum=atom['momentum'],
                        magmom=atom['magmom'],
                        charge=atom['charge'])
                   for atom in doc['atoms']['atoms']],
                  cell=doc['atoms']['cell'],
                  pbc=doc['atoms']['pbc'],
                  info=doc['atoms']['info'],
                  constraint=[dict2constraint(constraint_dict)
                              for constraint_dict in doc['atoms']['constraints']])
    results = doc['results']
    calc = SinglePointCalculator(energy=results.get('energy', None),
                                 forces=results.get('forces', None),
                                 stress=results.get('stress', None),
                                 atoms=atoms)
    atoms.set_calculator(calc)
    return atoms

# %%
initial_atoms = make_atoms_from_doc(co_set[9401]['initial_configuration'])
view(initial_atoms, viewer='x3d')
# Out:
# <html>
#
#  <head>
#
#   <title>ASE atomic visualization</title>
#
#   <link rel="stylesheet" type="text/css"
#
#    href="https://www.x3dom.org/x3dom/release/x3dom.css">
#
#   </link>
#
#   <script type="text/javascript"
#
#    src="https://www.x3dom.org/x3dom/release/x3dom.js">
#
#   </script>
#
#  </head>
#
#  <body>
#
#   <X3D>
#
#    <Scene>
#
#     <Transform translation="5.02 0.08 19.66">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="5.02 0.08 20.86">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 0.051 0.051" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.66">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="4.72 5.00 18.47">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.141 0.561 0.561" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.46">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="1.17 2.98 17.28">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.141 0.561 0.561" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.46">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="2.73 0.88 16.47">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.141 0.561 0.561" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.46">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="2.19 5.39 17.67">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.141 0.561 0.561" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.46">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="3.75 3.25 16.80">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.141 0.561 0.561" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.46">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="4.40 1.20 18.33">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.141 0.561 0.561" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.46">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="5.60 4.99 16.05">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.141 0.561 0.561" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.46">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="2.08 2.93 14.78">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.141 0.561 0.561" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.46">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="3.62 0.86 13.88">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.141 0.561 0.561" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.46">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="3.13 5.35 15.15">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.141 0.561 0.561" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.46">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="4.67 3.28 14.25">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.141 0.561 0.561" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.46">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="5.32 1.18 15.92">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.141 0.561 0.561" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.46">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="1.46 5.01 13.10">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.141 0.561 0.561" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.46">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="3.00 2.93 12.20">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.141 0.561 0.561" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.46">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="4.54 0.86 11.30">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.141 0.561 0.561" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.46">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="4.05 5.35 12.58">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.141 0.561 0.561" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.46">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="5.59 3.28 11.68">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.141 0.561 0.561" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.46">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="1.14 1.21 12.99">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.141 0.561 0.561" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.46">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#    </Scene>
#
#   </X3D>
#
#  </body>
#
# </html>

# %% [markdown]
# # Doping

# %%
import random

# %%
def doping(atoms,dopant,doping_conc):
    natoms = len(atoms)
    ncatatoms = natoms - 2
    ndopatoms = round(ncatatoms*doping_conc)
    doping_list = random.sample(range(2, natoms), ndopatoms)
    for a in doping_list:
        atoms[a].symbol = dopant
    return

# %% [markdown]
# # create slab (two types of doping function)

# %%
# Load functions required
# %run -i adsorbate_slab.py

# %%
def generate_absorbate_alloy_slab(bulk_id, miller_indices, adsorbate, doping_conc, dopant):
    #bulk
    bulk_atoms = bulk(bulk_id)
    bulk_cn_dict = find_bulk_cn_dict(bulk_atoms)
    #slab
    slab_list = make_slabs_from_bulk_atoms(bulk_atoms, miller_indices)
    #absorbate_slab
    adslab_list = [] ### add dictionary to note down face and dopant later ###

    for slab_atoms in slab_list:
        slab_atoms_tiled, slab_repeat = tile_atoms(atoms=slab_atoms,
                                                    min_x= 4.5,
                                                    min_y= 4.5)
        sites = find_adsorption_sites(slab_atoms_tiled)
        supercell_slab_atoms = slab_atoms_tiled.repeat((2, 2, 1))
        surface_atoms_list = find_surface_atoms_indices(bulk_cn_dict, supercell_slab_atoms)
        adsorbate.euler_rotate(phi=0., theta=0., psi=0.)
        natoms = len(slab_atoms_tiled)
        ndopatoms = round(natoms*doping_conc)
        print(ndopatoms,'doped in', natoms)
        for n in range(100):
            pure_slab_atoms = slab_atoms_tiled.copy()
            doping_list = random.sample(range(natoms), ndopatoms)
            for a in doping_list:
                pure_slab_atoms[a].symbol = dopant

            # Place a uranium atom on the adsorption site and then tag it with
            # a `1`, which is our way of saying that it is an adsorbate
            
            for site in sites:
                adsorption_vector = find_adsorption_vector(bulk_cn_dict, supercell_slab_atoms,
                                                        surface_atoms_list, site)
                # make a copy here so the original adsorbate is not further rotated
                # to align to the adsorption vector at each iteration
                aligned_adsorbate = adsorbate.copy()
                aligned_adsorbate.rotate(np.array([0., 0., 1.]), adsorption_vector) ###################need to be checked#######
                adslab = add_adsorbate_onto_slab(adsorbate=aligned_adsorbate,
                                                slab=pure_slab_atoms,
                                                site=site)
                adslab_list.append(adslab)
        print(len(adslab_list))
    return adslab_list

# %%
def generate_absorbate_cat_slab(bulk_id, miller_indices, adsorbate):
    #bulk
    bulk_atoms = bulk(bulk_id)
    bulk_cn_dict = find_bulk_cn_dict(bulk_atoms)
    #slab
    slab_list = make_slabs_from_bulk_atoms(bulk_atoms, miller_indices)
    #absorbate_slab
    adslab_list = [] ### add dictionary to note down face and dopant later ###
    for slab_atoms in slab_list:
            slab_atoms_tiled, slab_repeat = tile_atoms(atoms=slab_atoms,
                                                       min_x= 4.5,
                                                       min_y= 4.5)
            sites = find_adsorption_sites(slab_atoms_tiled)
            supercell_slab_atoms = slab_atoms_tiled.repeat((2, 2, 1))
            surface_atoms_list = find_surface_atoms_indices(bulk_cn_dict, supercell_slab_atoms)
            adsorbate.euler_rotate(phi=0., theta=0., psi=0.)

            # Place a uranium atom on the adsorption site and then tag it with
            # a `1`, which is our way of saying that it is an adsorbate
            
            for site in sites:
                adsorption_vector = find_adsorption_vector(bulk_cn_dict, supercell_slab_atoms,
                                                       surface_atoms_list, site)
                # make a copy here so the original adsorbate is not further rotated
                # to align to the adsorption vector at each iteration
                aligned_adsorbate = adsorbate.copy()
                aligned_adsorbate.rotate(np.array([0., 0., 1.]), adsorption_vector) ###################need to be checked#######
                adslab = add_adsorbate_onto_slab(adsorbate=aligned_adsorbate,
                                             slab=slab_atoms_tiled,
                                             site=site)
                adslab_list.append(adslab)
    return adslab_list

# %%
for ad in [CO,OH]:
    for face in [[1,0,0],[1,1,0],[1,1,1]]:
        for n in range(1,4):
            adslab_list = generate_absorbate_cat_slab(Cu_FCC_id, face, ad)
            for atoms in adslab_list:
                doping(atoms,'Zn',n/10)
            write_lmdb(adslab_list,'cu-zn/cu'+str(face[0])+str(face[1])+str(face[2])+str(ad.symbols).lower()+'_zn'+str(n/10)+'.lmdb')
            print('cu-zn/cu'+str(face[0])+str(face[1])+str(face[2])+str(ad.symbols).lower()+'_zn'+str(n/10)+'.lmdb')
# Out:
# cu-zn/cu100co_zn0.1.lmdb
# cu-zn/cu100co_zn0.2.lmdb
# cu-zn/cu100co_zn0.3.lmdb
# cu-zn/cu110co_zn0.1.lmdb
# cu-zn/cu110co_zn0.2.lmdb
# cu-zn/cu110co_zn0.3.lmdb
# cu-zn/cu111co_zn0.1.lmdb
# cu-zn/cu111co_zn0.2.lmdb
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x00000271AC7EFC70>>
# Traceback (most recent call last):
#   File "d:\SA\envs\ocp-models\lib\site-packages\ipykernel\ipkernel.py", line 775, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
# KeyboardInterrupt:
# cu-zn/cu111co_zn0.3.lmdb
# cu-zn/cu100oh_zn0.1.lmdb
# cu-zn/cu100oh_zn0.2.lmdb
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File messagestream.pyx:91, in scipy._lib.messagestream.MessageStream.close()
#
# TypeError: remove: path should be string, bytes or os.PathLike, not NoneType
# Exception ignored in: 'scipy._lib.messagestream.MessageStream.__dealloc__'
# Traceback (most recent call last):
#   File "messagestream.pyx", line 91, in scipy._lib.messagestream.MessageStream.close
# TypeError: remove: path should be string, bytes or os.PathLike, not NoneType
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[45], line 4
#       2 for face in [[1,0,0],[1,1,0],[1,1,1]]:
#       3     for n in range(1,4):
# ----> 4         adslab_list = generate_absorbate_cat_slab(Cu_FCC_id, face, ad)
#       5         for atoms in adslab_list:
#       6             doping(atoms,'Zn',n/10)
#
# Cell In[29], line 15, in generate_absorbate_cat_slab(bulk_id, miller_indices, adsorbate)
#      13 sites = find_adsorption_sites(slab_atoms_tiled)
#      14 supercell_slab_atoms = slab_atoms_tiled.repeat((2, 2, 1))
# ---> 15 surface_atoms_list = find_surface_atoms_indices(bulk_cn_dict, supercell_slab_atoms)
#      16 adsorbate.euler_rotate(phi=0., theta=0., psi=0.)
#      18 # Place a uranium atom on the adsorption site and then tag it with
#      19 # a `1`, which is our way of saying that it is an adsorbate
#
# File D:\SA\project\fairchem\test2\adsorbate_slab.py:363, in find_surface_atoms_indices(bulk_cn_dict, atoms)
#     361 if site.frac_coords[2] > center_of_mass[2]:
#     362     try:
# --> 363         cn = voronoi_nn.get_cn(struct, idx, use_weights=True)
#     364         cn = float('%.5f' % (round(cn, 5)))
#     365         # surface atoms are undercoordinated
#
# File d:\SA\envs\ocp-models\lib\site-packages\pymatgen\analysis\local_env.py:309, in NearNeighbors.get_cn(self, structure, n, use_weights, on_disorder)
#     289 """
#     290 Get coordination number, CN, of site with index n in structure.
#     291
#    (...)
#     306     cn (float): coordination number.
#     307 """
#     308 structure = _handle_disorder(structure, on_disorder)
# --> 309 siw = self.get_nn_info(structure, n)
#     310 return sum(e["weight"] for e in siw) if use_weights else len(siw)
#
# File d:\SA\envs\ocp-models\lib\site-packages\pymatgen\analysis\local_env.py:996, in VoronoiNN.get_nn_info(self, structure, n)
#     981 """
#     982 Get all near-neighbor sites as well as the associated image locations
#     983 and weights of the site with index n in structure
#    (...)
#     993         and its weight.
#     994 """
#     995 # Run the tessellation
# --> 996 nns = self.get_voronoi_polyhedra(structure, n)
#     998 # Extract the NN info
#     999 return self._extract_nn_info(structure, nns)
#
# File d:\SA\envs\ocp-models\lib\site-packages\pymatgen\analysis\local_env.py:771, in VoronoiNN.get_voronoi_polyhedra(self, structure, n)
#     768 # Run the Voronoi tessellation
#     769 qvoronoi_input = [site.coords for site in neighbors]
# --> 771 voro = Voronoi(qvoronoi_input)  # can give seg fault if cutoff is too small
#     773 # Extract data about the site in question
#     774 cell_info = self._extract_cell_info(0, neighbors, targets, voro, self.compute_adj_neighbors)
#
# File _qhull.pyx:2613, in scipy.spatial._qhull.Voronoi.__init__()
#
# File _qhull.pyx:258, in scipy.spatial._qhull._Qhull.__init__()
#
# File messagestream.pyx:29, in scipy._lib.messagestream.MessageStream.__cinit__()
#
# File d:\SA\envs\ocp-models\lib\tempfile.py:352, in mkstemp(suffix, prefix, dir, text)
#     349 else:
#     350     flags = _bin_openflags
# --> 352 return _mkstemp_inner(dir, prefix, suffix, flags, output_type)
#
# File d:\SA\envs\ocp-models\lib\tempfile.py:255, in _mkstemp_inner(dir, pre, suf, flags, output_type)
#     253 _sys.audit("tempfile.mkstemp", file)
#     254 try:
# --> 255     fd = _os.open(file, flags, 0o600)
#     256 except FileExistsError:
#     257     continue    # try again
#
# KeyboardInterrupt:

# %%
for ad in [CO,OH]:
    for face in [[1,0,0],[1,1,0],[1,1,1]]:
        for n in range(1,6):
            adslab_list = generate_absorbate_alloy_slab(Cu_FCC_id, face, ad, n/10, 'Ni')
            write_lmdb(adslab_list,'cu-ni/cu'+str(face[0])+str(face[1])+str(face[2])+str(ad.symbols).lower()+'_ni'+str(n/10)+'.lmdb')
            print('cu-ni/cu'+str(face[0])+str(face[1])+str(face[2])+str(ad.symbols).lower()+'_ni'+str(n/10)+'.lmdb')
# Out:
# 2 doped in 16
# 300
# cu-ni/cu100co_ni0.1.lmdb
# 3 doped in 16
# 300
# cu-ni/cu100co_ni0.2.lmdb
# 5 doped in 16
# 300
# cu-ni/cu100co_ni0.3.lmdb
# 6 doped in 16
# 300
# cu-ni/cu100co_ni0.4.lmdb
# 8 doped in 16
# 300
# cu-ni/cu100co_ni0.5.lmdb
# 3 doped in 32
# 400
# cu-ni/cu110co_ni0.1.lmdb
# 6 doped in 32
# 400
# cu-ni/cu110co_ni0.2.lmdb
# 10 doped in 32
# 400
# cu-ni/cu110co_ni0.3.lmdb
# 13 doped in 32
# 400
# cu-ni/cu110co_ni0.4.lmdb
# 16 doped in 32
# 400
# cu-ni/cu110co_ni0.5.lmdb
# 2 doped in 24
# 400
# cu-ni/cu111co_ni0.1.lmdb
# 5 doped in 24
# 400
# cu-ni/cu111co_ni0.2.lmdb
# 7 doped in 24
# 400
# cu-ni/cu111co_ni0.3.lmdb
# 10 doped in 24
# 400
# cu-ni/cu111co_ni0.4.lmdb
# 12 doped in 24
# 400
# cu-ni/cu111co_ni0.5.lmdb
# 2 doped in 16
# 300
# cu-ni/cu100oh_ni0.1.lmdb
# 3 doped in 16
# 300
# cu-ni/cu100oh_ni0.2.lmdb
# 5 doped in 16
# 300
# cu-ni/cu100oh_ni0.3.lmdb
# 6 doped in 16
# 300
# cu-ni/cu100oh_ni0.4.lmdb
# 8 doped in 16
# 300
# cu-ni/cu100oh_ni0.5.lmdb
# 3 doped in 32
# 400
# cu-ni/cu110oh_ni0.1.lmdb
# 6 doped in 32
# 400
# cu-ni/cu110oh_ni0.2.lmdb
# 10 doped in 32
# 400
# cu-ni/cu110oh_ni0.3.lmdb
# 13 doped in 32
# 400
# cu-ni/cu110oh_ni0.4.lmdb
# 16 doped in 32
# 400
# cu-ni/cu110oh_ni0.5.lmdb
# 2 doped in 24
# 400
# cu-ni/cu111oh_ni0.1.lmdb
# 5 doped in 24
# 400
# cu-ni/cu111oh_ni0.2.lmdb
# 7 doped in 24
# 400
# cu-ni/cu111oh_ni0.3.lmdb
# 10 doped in 24
# 400
# cu-ni/cu111oh_ni0.4.lmdb
# 12 doped in 24
# 400
# cu-ni/cu111oh_ni0.5.lmdb

# %%
adslab_list = generate_absorbate_cat_slab(Cu_FCC_id, [1,1,1], CO)
doping(adslab_list[0],'Ni',0.5)
view(adslab_list[0], viewer='x3d')
# Out:
# <html>
#
#  <head>
#
#   <title>ASE atomic visualization</title>
#
#   <link rel="stylesheet" type="text/css"
#
#    href="https://www.x3dom.org/x3dom/release/x3dom.css">
#
#   </link>
#
#   <script type="text/javascript"
#
#    src="https://www.x3dom.org/x3dom/release/x3dom.js">
#
#   </script>
#
#  </head>
#
#  <body>
#
#   <X3D>
#
#    <Scene>
#
#     <Transform translation="2.56 0.00 26.04">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="2.56 0.00 27.24">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 0.051 0.051" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.66">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="0.00 1.48 13.59">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.314 0.816 0.314" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.24">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-0.00 0.00 17.77">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="1.28 0.74 15.68">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.314 0.816 0.314" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.24">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="0.00 1.48 19.86">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.314 0.816 0.314" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.24">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="2.56 0.00 24.04">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.314 0.816 0.314" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.24">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="1.28 0.74 21.95">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.314 0.816 0.314" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.24">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-1.28 3.70 13.59">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.314 0.816 0.314" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.24">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-1.28 2.22 17.77">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.314 0.816 0.314" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.24">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="0.00 2.96 15.68">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-1.28 3.70 19.86">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.314 0.816 0.314" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.24">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="1.28 2.22 24.04">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="0.00 2.96 21.95">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="2.56 1.48 13.59">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.314 0.816 0.314" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.24">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="2.56 0.00 17.77">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="3.84 0.74 15.68">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="2.56 1.48 19.86">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="5.12 0.00 24.04">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.314 0.816 0.314" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.24">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="3.84 0.74 21.95">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="1.28 3.70 13.59">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.314 0.816 0.314" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.24">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="1.28 2.22 17.77">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="2.56 2.96 15.68">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="1.28 3.70 19.86">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="3.84 2.22 24.04">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.314 0.816 0.314" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.24">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="2.56 2.96 21.95">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#    </Scene>
#
#   </X3D>
#
#  </body>
#
# </html>

# %%
write('Cu-Ni.png', adslab_list[0])

# %%
adslab_list[100]
# Out:
# Atoms(symbols='OHCu3NiCu2Ni3Cu2NiCu2Ni3CuNi3CuNiCu', pbc=True, cell=[[5.12123783330632, 0.0, 0.0], [-2.5606189166531585, 4.4351220624652505, 4.703780640173183e-16], [0.0, 0.0, 37.633258629110934]], tags=..., constraint=FixAtoms(indices=[2, 3, 4, 5, 8, 9, 10, 11, 14, 15, 16, 17, 20, 21, 22, 23]))

# %%
dataset = SinglePointLmdbDataset({"src": "lmdbs/co_dev.lmdb"})
len(dataset)
# Out:
# 3820

# %% [markdown]
# # To LMDB

# %%
a2g = AtomsToGraphs(
    max_neigh=50,
    radius=6,
    r_energy=False,
    r_forces=False,
    r_distances=False,
    r_edges=True,
    r_fixed=True,
)

# %%
def write_lmdb(atom_list, name):
    db = lmdb.open(
    name,
    #map_size=1099511627776 * 2,
    map_size = 1024 * 1024 * 1024 *2,
    subdir=False,
    meminit=False,
    map_async=True,)
    
    idx = 0
    for item in atom_list:
        # Extract Data object
        data_objects = a2g.convert(item)
        initial_struc = data_objects
    
        initial_struc.sid = idx  # arbitrary unique identifier 
    
        # no neighbor edge case check
        if initial_struc.edge_index.shape[1] == 0:
            print("no neighbors", idx)
            continue
    
        # Write to LMDB
        txn = db.begin(write=True)
        txn.put(f"{idx}".encode("ascii"), pickle.dumps(initial_struc, protocol=-1))
        txn.commit()
        db.sync()
        idx += 1
    db.close()

# %%
write_lmdb(adslab_list,"cu/cu100oh.lmdb")

# %%
dataset = SinglePointLmdbDataset({"src": "cu/cu111oh.lmdb"})
len(dataset)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 dataset = SinglePointLmdbDataset({"src": "cu/cu111oh.lmdb"})
#       2 len(dataset)
#
# File D:\SA\project\fairchem\ocpmodels\datasets\lmdb_dataset.py:220, in SinglePointLmdbDataset.__init__(self, config, transform)
#     219 def __init__(self, config, transform=None) -> None:
# --> 220     super(SinglePointLmdbDataset, self).__init__(config, transform)
#     221     warnings.warn(
#     222         "SinglePointLmdbDataset is deprecated and will be removed in the future."
#     223         "Please use 'LmdbDataset' instead.",
#     224         stacklevel=3,
#     225     )
#
# File D:\SA\project\fairchem\ocpmodels\datasets\lmdb_dataset.py:61, in LmdbDataset.__init__(self, config, transform)
#      59 if not self.path.is_file():
#      60     db_paths = sorted(self.path.glob("*.lmdb"))
# ---> 61     assert len(db_paths) > 0, f"No LMDBs found in '{self.path}'"
#      63     self.metadata_path = self.path / "metadata.npz"
#      65     self._keys = []
#
# AssertionError: No LMDBs found in 'cu\cu111oh.lmdb'
